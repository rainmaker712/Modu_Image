# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import os
import sys
import tarfile
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
import numpy as np
import cv2

#얼굴 추출하기위한 데이터 파일
CASC_PATH = './emotion-recognition/haarcascade_frontalface_default.xml'
cascade_classifier = cv2.CascadeClassifier(CASC_PATH)
SIZE_FACE = 48
EMOTIONS = ['angry', 'disgusted', 'fearful', 'happy', 'sad', 'surprised', 'neutral']

# Config the matlotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
def format_image(image):
  if len(image.shape) > 2 and image.shape[2] == 3:
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  else:
    image = cv2.imdecode(image, cv2.CV_LOAD_IMAGE_GRAYSCALE)
  faces = cascade_classifier.detectMultiScale(
      image,
      scaleFactor = 1.3,
      minNeighbors = 5
  )
  # None is we don't found an image
  if not len(faces) > 0:
    return None
  max_area_face = faces[0]
  for face in faces:
    if face[2] * face[3] > max_area_face[2] * max_area_face[3]:
      max_area_face = face
  # Chop image to face
  face = max_area_face
  image = image[face[1]:(face[1] + face[2]), face[0]:(face[0] + face[3])]
  # Resize image to network size
  try:
    image = cv2.resize(image, (SIZE_FACE, SIZE_FACE), interpolation = cv2.INTER_CUBIC) / 255.
  except Exception:
    print("[+] Problem during resize")
    return None
  # cv2.imshow("Lol", image)
  # cv2.waitKey(0)
  return image

# %%
#Image Check
import os, random
dir_name = "/home/ryan/Pictures/momca_pic/"
"""0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral"""
folder_names = ["0","1","2","3","4","5","6"]
for folder_name in folder_names :
    print ("folder_name : " + folder_name)
    im_name = random.choice(os.listdir(dir_name+ "/" + folder_name))
    print("im_name : " + im_name)
    im_file = dir_name + "/" +folder_name + "/"  +im_name
    print("im_file : " + im_file)
    readImage = cv.imread(im_file)
    if readImage is None :
        print("readImage is None")
        continue
    
    formatImage = format_image(cv.imread(im_file))
    try:
        plt.imsave('reshapeImage.png', formatImage, cmap=cm.gray)
    except:
        print("pass cause exception")
        continue
    im_file = "./reshapeImage.png"
    display(Image(filename=im_file))
# Out:
# folder_name : 0
# im_name : angry-028.jpg
# im_file : emotion-recognition/0/angry-028.jpg
# pass cause exception
# folder_name : 1
# im_name : Disgust-1.jpg
# im_file : emotion-recognition/1/Disgust-1.jpg
# folder_name : 2
# im_name : FEARFACTOR_BOLUM_4_360.jpg
# im_file : emotion-recognition/2/FEARFACTOR_BOLUM_4_360.jpg
# folder_name : 3
# im_name : sophie-flap-happy.jpg
# im_file : emotion-recognition/3/sophie-flap-happy.jpg
# readImage is None
# folder_name : 4
# im_name : 87956-566x848-NeutralMakeup8.jpg
# im_file : emotion-recognition/4/87956-566x848-NeutralMakeup8.jpg
# folder_name : 5
# im_name : sad_girl_WE036043.jpg
# im_file : emotion-recognition/5/sad_girl_WE036043.jpg
# folder_name : 6
# im_name : luis-surprise-surprresa-1.jpg
# im_file : emotion-recognition/6/luis-surprise-surprresa-1.jpg

# %%
pixel_depth = 255.0  # Number of levels per pixel.
train_folders = ['emotion-recognition/0', 'emotion-recognition/1', 'emotion-recognition/2', 'emotion-recognition/3', 'emotion-recognition/4', 'emotion-recognition/5', 'emotion-recognition/6']


def load_letter(folder, min_num_images):
  """Load the data for a single letter label."""
  image_files = os.listdir(folder)
  dataset = np.ndarray(shape=(len(image_files), SIZE_FACE, SIZE_FACE),
                         dtype=np.float32)
  print(folder)
  num_images = 0
  for image in image_files:
    image_file = os.path.join(folder, image)
    try:
      
    
      SourceImage = cv.imread(image_file)
      if SourceImage is None :
        continue
      print('SourceImage',SourceImage.shape)
      image_data = format_image(SourceImage)
      if image_data is None :
        continue
      print('image_data shape',image_data.shape)
      
   
        
      if image_data.shape != (SIZE_FACE, SIZE_FACE):
        raise Exception('Unexpected image shape: %s' % str(image_data.shape))
      dataset[num_images, :, :] = image_data
      num_images = num_images + 1
    except IOError as e:
      print('Could not read:', image_file, ':', e, '- it\'s ok, skipping.')
    
  dataset = dataset[0:num_images, :, :]
  if num_images < min_num_images:
    raise Exception('Many fewer images than expected: %d < %d' %
                    (num_images, min_num_images))
    
  print('Full dataset tensor:', dataset.shape)
  print('Mean:', np.mean(dataset))
  print('Standard deviation:', np.std(dataset))
  return dataset
        
def maybe_pickle(data_folders, min_num_images_per_class, force=False):
  dataset_names = []
  for folder in data_folders:
    set_filename = folder + '.pickle'
    dataset_names.append(set_filename)
    if os.path.exists(set_filename) and not force:
      # You may override by setting force=True.
      print('%s already present - Skipping pickling.' % set_filename)
    else:
      print('Pickling %s.' % set_filename)
      dataset = load_letter(folder, min_num_images_per_class)
      try:
        with open(set_filename, 'wb') as f:
          pickle.dump(dataset, f, pickle.HIGHEST_PROTOCOL)
      except Exception as e:
        print('Unable to save data to', set_filename, ':', e)
  
  return dataset_names

train_datasets = maybe_pickle(train_folders, 1)
# Out:
# Pickling emotion-recognition/0.pickle.
# emotion-recognition/0
# SourceImage (450, 750, 3)
# SourceImage (813, 1024, 3)
# SourceImage (1199, 1601, 3)
# image_data shape (32, 32)
# SourceImage (2000, 3000, 3)
# SourceImage (749, 1123, 3)
# image_data shape (32, 32)
# SourceImage (1360, 2048, 3)
# image_data shape (32, 32)
# SourceImage (555, 800, 3)
# image_data shape (32, 32)
# SourceImage (770, 1012, 3)
# SourceImage (1400, 2800, 3)
# image_data shape (32, 32)
# SourceImage (565, 849, 3)
# image_data shape (32, 32)
# SourceImage (800, 979, 3)
# image_data shape (32, 32)
# SourceImage (300, 300, 3)
# image_data shape (32, 32)
# SourceImage (450, 600, 3)
# SourceImage (309, 388, 3)
# image_data shape (32, 32)
# SourceImage (2667, 4000, 3)
# image_data shape (32, 32)
# SourceImage (1129, 1600, 3)
# image_data shape (32, 32)
# SourceImage (1131, 1698, 3)
# image_data shape (32, 32)
# SourceImage (533, 800, 3)
# image_data shape (32, 32)
# Full dataset tensor: (13, 32, 32)
# Mean: 0.606231
# Standard deviation: 0.217711
# Pickling emotion-recognition/1.pickle.
# emotion-recognition/1
# SourceImage (427, 306, 3)
# image_data shape (32, 32)
# SourceImage (934, 909, 3)
# SourceImage (673, 433, 3)
# image_data shape (32, 32)
# SourceImage (535, 800, 3)
# image_data shape (32, 32)
# SourceImage (375, 300, 3)
# image_data shape (32, 32)
# SourceImage (514, 935, 3)
# SourceImage (360, 360, 3)
# SourceImage (1056, 716, 3)
# image_data shape (32, 32)
# SourceImage (493, 460, 3)
# image_data shape (32, 32)
# SourceImage (900, 600, 3)
# image_data shape (32, 32)
# SourceImage (787, 1075, 3)
# image_data shape (32, 32)
# SourceImage (450, 299, 3)
# image_data shape (32, 32)
# SourceImage (447, 444, 3)
# image_data shape (32, 32)
# SourceImage (426, 640, 3)
# SourceImage (836, 896, 3)
# image_data shape (32, 32)
# SourceImage (500, 339, 3)
# SourceImage (287, 200, 3)
# image_data shape (32, 32)
# SourceImage (152, 211, 3)
# image_data shape (32, 32)
# SourceImage (352, 300, 3)
# SourceImage (525, 350, 3)
# SourceImage (494, 846, 3)
# image_data shape (32, 32)
# SourceImage (1000, 2000, 3)
# image_data shape (32, 32)
# SourceImage (680, 1024, 3)
# image_data shape (32, 32)
# SourceImage (3500, 2800, 3)
# SourceImage (297, 198, 3)
# image_data shape (32, 32)
# SourceImage (300, 200, 3)
# image_data shape (32, 32)
# SourceImage (1431, 1552, 3)
# image_data shape (32, 32)
# SourceImage (900, 788, 3)
# image_data shape (32, 32)
# SourceImage (1583, 1594, 3)
# image_data shape (32, 32)
# SourceImage (1757, 1844, 3)
# image_data shape (32, 32)
# SourceImage (450, 600, 3)
# SourceImage (579, 579, 3)
# image_data shape (32, 32)
# SourceImage (500, 500, 3)
# image_data shape (32, 32)
# SourceImage (1300, 957, 3)
# image_data shape (32, 32)
# SourceImage (818, 1196, 3)
# image_data shape (32, 32)
# SourceImage (240, 153, 3)
# SourceImage (1300, 953, 3)
# image_data shape (32, 32)
# SourceImage (296, 200, 3)
# image_data shape (32, 32)
# SourceImage (957, 1300, 3)
# image_data shape (32, 32)
# SourceImage (500, 500, 3)
# image_data shape (32, 32)
# SourceImage (349, 623, 3)
# image_data shape (32, 32)
# SourceImage (1068, 1600, 3)
# image_data shape (32, 32)
# SourceImage (564, 846, 3)
# image_data shape (32, 32)
# SourceImage (1338, 1278, 3)
# image_data shape (32, 32)
# SourceImage (413, 620, 3)
# image_data shape (32, 32)
# SourceImage (235, 360, 3)
# SourceImage (267, 400, 3)
# SourceImage (1300, 957, 3)
# image_data shape (32, 32)
# SourceImage (450, 287, 3)
# SourceImage (716, 553, 3)
# image_data shape (32, 32)
# SourceImage (320, 500, 3)
# image_data shape (32, 32)
# SourceImage (357, 336, 3)
# image_data shape (32, 32)
# SourceImage (184, 215, 3)
# image_data shape (32, 32)
# SourceImage (333, 305, 3)
# image_data shape (32, 32)
# SourceImage (185, 230, 3)
# SourceImage (281, 200, 3)
# Full dataset tensor: (41, 32, 32)
# Mean: 0.516915
# Standard deviation: 0.261076
# Pickling emotion-recognition/2.pickle.
# emotion-recognition/2
# SourceImage (402, 717, 3)
# image_data shape (32, 32)
# SourceImage (350, 350, 3)
# SourceImage (524, 424, 3)
# SourceImage (240, 180, 3)
# image_data shape (32, 32)
# SourceImage (400, 300, 3)
# image_data shape (32, 32)
# SourceImage (370, 556, 3)
# image_data shape (32, 32)
# SourceImage (480, 853, 3)
# image_data shape (32, 32)
# SourceImage (842, 596, 3)
# SourceImage (277, 450, 3)
# SourceImage (1300, 1083, 3)
# image_data shape (32, 32)
# SourceImage (150, 175, 3)
# image_data shape (32, 32)
# SourceImage (400, 269, 3)
# SourceImage (455, 450, 3)
# image_data shape (32, 32)
# SourceImage (300, 400, 3)
# image_data shape (32, 32)
# SourceImage (140, 129, 3)
# image_data shape (32, 32)
# SourceImage (795, 796, 3)
# image_data shape (32, 32)
# SourceImage (480, 640, 3)
# image_data shape (32, 32)
# SourceImage (1300, 976, 3)
# SourceImage (700, 495, 3)
# SourceImage (641, 500, 3)
# image_data shape (32, 32)
# SourceImage (1239, 1550, 3)
# SourceImage (220, 220, 3)
# image_data shape (32, 32)
# SourceImage (450, 630, 3)
# image_data shape (32, 32)
# SourceImage (1024, 812, 3)
# image_data shape (32, 32)
# SourceImage (807, 1482, 3)
# image_data shape (32, 32)
# SourceImage (1732, 1674, 3)
# image_data shape (32, 32)
# SourceImage (1345, 1100, 3)
# image_data shape (32, 32)
# SourceImage (250, 300, 3)
# SourceImage (348, 504, 3)
# image_data shape (32, 32)
# SourceImage (150, 175, 3)
# image_data shape (32, 32)
# SourceImage (1300, 958, 3)
# image_data shape (32, 32)
# SourceImage (577, 468, 3)
# image_data shape (32, 32)
# SourceImage (520, 680, 3)
# image_data shape (32, 32)
# SourceImage (905, 1024, 3)
# SourceImage (500, 375, 3)
# SourceImage (664, 600, 3)
# image_data shape (32, 32)
# SourceImage (450, 450, 3)
# image_data shape (32, 32)
# SourceImage (849, 1133, 3)
# image_data shape (32, 32)
# SourceImage (360, 480, 3)
# image_data shape (32, 32)
# SourceImage (732, 640, 3)
# image_data shape (32, 32)
# SourceImage (666, 1000, 3)
# image_data shape (32, 32)
# SourceImage (375, 250, 3)
# image_data shape (32, 32)
# SourceImage (300, 400, 3)
# image_data shape (32, 32)
# SourceImage (825, 1450, 3)
# SourceImage (280, 225, 3)
# image_data shape (32, 32)
# SourceImage (1600, 990, 3)
# SourceImage (776, 600, 3)
# image_data shape (32, 32)
# SourceImage (1000, 1000, 3)
# SourceImage (800, 538, 3)
# image_data shape (32, 32)
# SourceImage (480, 853, 3)
# image_data shape (32, 32)
# SourceImage (480, 853, 3)
# image_data shape (32, 32)
# SourceImage (365, 504, 3)
# image_data shape (32, 32)
# SourceImage (485, 736, 3)
# image_data shape (32, 32)
# SourceImage (300, 205, 3)
# image_data shape (32, 32)
# SourceImage (957, 1300, 3)
# image_data shape (32, 32)
# SourceImage (427, 420, 3)
# SourceImage (670, 451, 3)
# image_data shape (32, 32)
# SourceImage (1050, 1680, 3)
# image_data shape (32, 32)
# SourceImage (594, 416, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# image_data shape (32, 32)
# SourceImage (800, 880, 3)
# SourceImage (480, 853, 3)
# image_data shape (32, 32)
# SourceImage (400, 600, 3)
# image_data shape (32, 32)
# SourceImage (648, 864, 3)
# image_data shape (32, 32)
# SourceImage (1152, 1728, 3)
# image_data shape (32, 32)
# SourceImage (400, 600, 3)
# image_data shape (32, 32)
# SourceImage (500, 500, 3)
# image_data shape (32, 32)
# SourceImage (475, 468, 3)
# SourceImage (615, 538, 3)
# image_data shape (32, 32)
# SourceImage (1600, 800, 3)
# SourceImage (860, 600, 3)
# SourceImage (452, 582, 3)
# image_data shape (32, 32)
# SourceImage (1024, 706, 3)
# image_data shape (32, 32)
# SourceImage (600, 450, 3)
# image_data shape (32, 32)
# SourceImage (429, 300, 3)
# SourceImage (739, 492, 3)
# SourceImage (520, 520, 3)
# image_data shape (32, 32)
# SourceImage (320, 240, 3)
# SourceImage (273, 273, 3)
# SourceImage (826, 600, 3)
# SourceImage (400, 360, 3)
# image_data shape (32, 32)
# SourceImage (600, 800, 3)
# image_data shape (32, 32)
# SourceImage (780, 520, 3)
# SourceImage (1158, 832, 3)
# image_data shape (32, 32)
# SourceImage (595, 600, 3)
# SourceImage (220, 220, 3)
# SourceImage (360, 640, 3)
# image_data shape (32, 32)
# SourceImage (1081, 2000, 3)
# SourceImage (1325, 1024, 3)
# image_data shape (32, 32)
# SourceImage (1131, 1600, 3)
# image_data shape (32, 32)
# SourceImage (608, 608, 3)
# image_data shape (32, 32)
# SourceImage (444, 356, 3)
# image_data shape (32, 32)
# SourceImage (2700, 1800, 3)
# image_data shape (32, 32)
# SourceImage (902, 784, 3)
# image_data shape (32, 32)
# SourceImage (1095, 730, 3)
# SourceImage (184, 215, 3)
# SourceImage (400, 316, 3)
# SourceImage (1300, 969, 3)
# image_data shape (32, 32)
# SourceImage (768, 1024, 3)
# SourceImage (316, 504, 3)
# SourceImage (507, 500, 3)
# image_data shape (32, 32)
# SourceImage (468, 500, 3)
# image_data shape (32, 32)
# SourceImage (880, 660, 3)
# image_data shape (32, 32)
# SourceImage (474, 640, 3)
# image_data shape (32, 32)
# SourceImage (800, 600, 3)
# image_data shape (32, 32)
# SourceImage (400, 267, 3)
# image_data shape (32, 32)
# SourceImage (537, 815, 3)
# SourceImage (100, 100, 3)
# image_data shape (32, 32)
# SourceImage (200, 200, 3)
# SourceImage (675, 900, 3)
# image_data shape (32, 32)
# SourceImage (412, 576, 3)
# SourceImage (579, 800, 3)
# image_data shape (32, 32)
# SourceImage (744, 770, 3)
# SourceImage (768, 1024, 3)
# SourceImage (1960, 3000, 3)
# image_data shape (32, 32)
# SourceImage (595, 511, 3)
# SourceImage (847, 600, 3)
# SourceImage (579, 785, 3)
# image_data shape (32, 32)
# SourceImage (281, 500, 3)
# image_data shape (32, 32)
# SourceImage (525, 421, 3)
# image_data shape (32, 32)
# SourceImage (803, 811, 3)
# image_data shape (32, 32)
# SourceImage (352, 540, 3)
# image_data shape (32, 32)
# SourceImage (449, 607, 3)
# SourceImage (338, 600, 3)
# SourceImage (189, 239, 3)
# SourceImage (312, 447, 3)
# image_data shape (32, 32)
# SourceImage (304, 228, 3)
# SourceImage (900, 597, 3)
# image_data shape (32, 32)
# SourceImage (900, 1600, 3)
# image_data shape (32, 32)
# SourceImage (1600, 1272, 3)
# SourceImage (595, 600, 3)
# SourceImage (364, 463, 3)
# image_data shape (32, 32)
# SourceImage (1333, 1000, 3)
# image_data shape (32, 32)
# SourceImage (710, 575, 3)
# image_data shape (32, 32)
# SourceImage (576, 768, 3)
# image_data shape (32, 32)
# SourceImage (1473, 1171, 3)
# image_data shape (32, 32)
# SourceImage (403, 604, 3)
# image_data shape (32, 32)
# SourceImage (220, 220, 3)
# image_data shape (32, 32)
# SourceImage (768, 1024, 3)
# SourceImage (3270, 2100, 3)
# image_data shape (32, 32)
# SourceImage (1329, 1974, 3)
# image_data shape (32, 32)
# SourceImage (240, 320, 3)
# image_data shape (32, 32)
# SourceImage (1000, 861, 3)
# SourceImage (1143, 699, 3)
# image_data shape (32, 32)
# SourceImage (219, 220, 3)
# SourceImage (389, 460, 3)
# SourceImage (459, 640, 3)
# image_data shape (32, 32)
# SourceImage (374, 300, 3)
# image_data shape (32, 32)
# SourceImage (401, 700, 3)
# SourceImage (368, 504, 3)
# image_data shape (32, 32)
# SourceImage (800, 553, 3)
# image_data shape (32, 32)
# SourceImage (1066, 800, 3)
# SourceImage (600, 450, 3)
# image_data shape (32, 32)
# SourceImage (1300, 957, 3)
# SourceImage (553, 640, 3)
# SourceImage (320, 240, 3)
# image_data shape (32, 32)
# SourceImage (1006, 795, 3)
# SourceImage (1021, 677, 3)
# image_data shape (32, 32)
# SourceImage (255, 340, 3)
# image_data shape (32, 32)
# SourceImage (240, 320, 3)
# image_data shape (32, 32)
# SourceImage (576, 768, 3)
# image_data shape (32, 32)
# SourceImage (599, 420, 3)
# SourceImage (540, 720, 3)
# image_data shape (32, 32)
# SourceImage (317, 527, 3)
# SourceImage (256, 256, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# image_data shape (32, 32)
# SourceImage (326, 325, 3)
# image_data shape (32, 32)
# SourceImage (576, 768, 3)
# SourceImage (400, 620, 3)
# image_data shape (32, 32)
# SourceImage (1440, 1440, 3)
# image_data shape (32, 32)
# SourceImage (546, 380, 3)
# image_data shape (32, 32)
# SourceImage (507, 501, 3)
# SourceImage (261, 511, 3)
# image_data shape (32, 32)
# SourceImage (424, 283, 3)
# SourceImage (1024, 1536, 3)
# image_data shape (32, 32)
# SourceImage (450, 389, 3)
# image_data shape (32, 32)
# SourceImage (693, 693, 3)
# SourceImage (301, 300, 3)
# image_data shape (32, 32)
# SourceImage (581, 640, 3)
# SourceImage (250, 200, 3)
# image_data shape (32, 32)
# SourceImage (768, 1024, 3)
# image_data shape (32, 32)
# SourceImage (615, 1001, 3)
# image_data shape (32, 32)
# SourceImage (567, 743, 3)
# image_data shape (32, 32)
# SourceImage (240, 320, 3)
# image_data shape (32, 32)
# SourceImage (360, 640, 3)
# image_data shape (32, 32)
# SourceImage (640, 384, 3)
# image_data shape (32, 32)
# SourceImage (229, 156, 3)
# image_data shape (32, 32)
# SourceImage (400, 268, 3)
# SourceImage (640, 480, 3)
# SourceImage (774, 1032, 3)
# image_data shape (32, 32)
# SourceImage (576, 768, 3)
# image_data shape (32, 32)
# SourceImage (200, 200, 3)
# image_data shape (32, 32)
# SourceImage (448, 336, 3)
# SourceImage (711, 948, 3)
# SourceImage (576, 768, 3)
# image_data shape (32, 32)
# SourceImage (600, 450, 3)
# image_data shape (32, 32)
# SourceImage (640, 480, 3)
# image_data shape (32, 32)
# SourceImage (334, 594, 3)
# image_data shape (32, 32)
# SourceImage (705, 509, 3)
# image_data shape (32, 32)
# SourceImage (280, 225, 3)
# image_data shape (32, 32)
# SourceImage (523, 550, 3)
# image_data shape (32, 32)
# SourceImage (640, 529, 3)
# SourceImage (2401, 1694, 3)
# image_data shape (32, 32)
# SourceImage (520, 672, 3)
# SourceImage (646, 500, 3)
# SourceImage (225, 200, 3)
# image_data shape (32, 32)
# SourceImage (800, 600, 3)
# image_data shape (32, 32)
# SourceImage (480, 853, 3)
# SourceImage (475, 335, 3)
# image_data shape (32, 32)
# SourceImage (300, 281, 3)
# SourceImage (548, 400, 3)
# SourceImage (285, 180, 3)
# image_data shape (32, 32)
# SourceImage (600, 400, 3)
# image_data shape (32, 32)
# SourceImage (1000, 1000, 3)
# image_data shape (32, 32)
# SourceImage (1600, 1082, 3)
# image_data shape (32, 32)
# SourceImage (530, 640, 3)
# image_data shape (32, 32)
# SourceImage (900, 888, 3)
# image_data shape (32, 32)
# SourceImage (482, 900, 3)
# SourceImage (768, 1024, 3)
# image_data shape (32, 32)
# SourceImage (2158, 1521, 3)
# SourceImage (1000, 989, 3)
# image_data shape (32, 32)
# SourceImage (1000, 717, 3)
# SourceImage (1186, 1203, 3)
# image_data shape (32, 32)
# SourceImage (480, 853, 3)
# image_data shape (32, 32)
# SourceImage (456, 600, 3)
# image_data shape (32, 32)
# SourceImage (959, 959, 3)
# image_data shape (32, 32)
# SourceImage (640, 640, 3)
# image_data shape (32, 32)
# SourceImage (1300, 957, 3)
# image_data shape (32, 32)
# SourceImage (1024, 1280, 3)
# image_data shape (32, 32)
# SourceImage (256, 500, 3)
# SourceImage (400, 400, 3)
# SourceImage (2100, 1500, 3)
# image_data shape (32, 32)
# SourceImage (240, 320, 3)
# image_data shape (32, 32)
# SourceImage (1300, 1017, 3)
# image_data shape (32, 32)
# SourceImage (1222, 873, 3)
# image_data shape (32, 32)
# SourceImage (1024, 690, 3)
# SourceImage (1510, 1000, 3)
# image_data shape (32, 32)
# SourceImage (400, 300, 3)
# image_data shape (32, 32)
# SourceImage (386, 650, 3)
# image_data shape (32, 32)
# SourceImage (900, 750, 3)
# image_data shape (32, 32)
# SourceImage (225, 225, 3)
# SourceImage (646, 814, 3)
# image_data shape (32, 32)
# SourceImage (240, 320, 3)
# image_data shape (32, 32)
# SourceImage (250, 250, 3)
# SourceImage (594, 416, 3)
# image_data shape (32, 32)
# SourceImage (1085, 900, 3)
# image_data shape (32, 32)
# SourceImage (563, 900, 3)
# SourceImage (500, 500, 3)
# SourceImage (1024, 1280, 3)
# SourceImage (401, 299, 3)
# image_data shape (32, 32)
# SourceImage (400, 273, 3)
# SourceImage (450, 338, 3)
# SourceImage (915, 1405, 3)
# image_data shape (32, 32)
# SourceImage (667, 480, 3)
# SourceImage (491, 533, 3)
# image_data shape (32, 32)
# SourceImage (726, 520, 3)
# image_data shape (32, 32)
# SourceImage (1333, 1000, 3)
# image_data shape (32, 32)
# SourceImage (934, 940, 3)
# SourceImage (1500, 1178, 3)
# image_data shape (32, 32)
# SourceImage (1015, 900, 3)
# image_data shape (32, 32)
# SourceImage (2663, 2478, 3)
# image_data shape (32, 32)
# SourceImage (306, 404, 3)
# SourceImage (594, 800, 3)
# SourceImage (576, 768, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# SourceImage (4902, 2443, 3)
# image_data shape (32, 32)
# SourceImage (375, 500, 3)
# image_data shape (32, 32)
# SourceImage (800, 1280, 3)
# SourceImage (576, 768, 3)
# SourceImage (921, 618, 3)
# image_data shape (32, 32)
# SourceImage (337, 600, 3)
# SourceImage (600, 600, 3)
# image_data shape (32, 32)
# SourceImage (865, 570, 3)
# image_data shape (32, 32)
# SourceImage (655, 650, 3)
# image_data shape (32, 32)
# SourceImage (600, 424, 3)
# SourceImage (475, 329, 3)
# SourceImage (500, 347, 3)
# SourceImage (475, 337, 3)
# image_data shape (32, 32)
# SourceImage (1080, 1920, 3)
# SourceImage (753, 511, 3)
# image_data shape (32, 32)
# SourceImage (675, 675, 3)
# image_data shape (32, 32)
# SourceImage (306, 200, 3)
# image_data shape (32, 32)
# SourceImage (400, 620, 3)
# SourceImage (768, 1024, 3)
# SourceImage (150, 150, 3)
# SourceImage (586, 800, 3)
# SourceImage (1715, 1500, 3)
# SourceImage (800, 933, 3)
# image_data shape (32, 32)
# SourceImage (425, 700, 3)
# image_data shape (32, 32)
# SourceImage (375, 500, 3)
# image_data shape (32, 32)
# SourceImage (424, 283, 3)
# SourceImage (576, 768, 3)
# image_data shape (32, 32)
# SourceImage (576, 768, 3)
# image_data shape (32, 32)
# SourceImage (1024, 729, 3)
# image_data shape (32, 32)
# SourceImage (521, 400, 3)
# image_data shape (32, 32)
# SourceImage (980, 700, 3)
# image_data shape (32, 32)
# SourceImage (300, 273, 3)
# image_data shape (32, 32)
# SourceImage (394, 700, 3)
# image_data shape (32, 32)
# SourceImage (1125, 750, 3)
# image_data shape (32, 32)
# SourceImage (1024, 768, 3)
# image_data shape (32, 32)
# SourceImage (240, 320, 3)
# SourceImage (1074, 1522, 3)
# image_data shape (32, 32)
# SourceImage (552, 626, 3)
# image_data shape (32, 32)
# SourceImage (400, 400, 3)
# SourceImage (1067, 1600, 3)
# SourceImage (480, 853, 3)
# image_data shape (32, 32)
# SourceImage (465, 465, 3)
# image_data shape (32, 32)
# SourceImage (1000, 1000, 3)
# image_data shape (32, 32)
# SourceImage (220, 220, 3)
# image_data shape (32, 32)
# SourceImage (480, 640, 3)
# image_data shape (32, 32)
# SourceImage (333, 600, 3)
# image_data shape (32, 32)
# SourceImage (373, 500, 3)
# SourceImage (950, 600, 3)
# SourceImage (270, 216, 3)
# image_data shape (32, 32)
# SourceImage (1300, 946, 3)
# SourceImage (1024, 504, 3)
# image_data shape (32, 32)
# SourceImage (696, 805, 3)
# SourceImage (162, 220, 3)
# image_data shape (32, 32)
# SourceImage (513, 400, 3)
# image_data shape (32, 32)
# SourceImage (1000, 2000, 3)
# SourceImage (480, 370, 3)
# image_data shape (32, 32)
# SourceImage (900, 675, 3)
# image_data shape (32, 32)
# SourceImage (1081, 1600, 3)
# image_data shape (32, 32)
# SourceImage (563, 930, 3)
# SourceImage (1125, 1500, 3)
# image_data shape (32, 32)
# SourceImage (594, 423, 3)
# image_data shape (32, 32)
# SourceImage (1600, 1127, 3)
# SourceImage (100, 100, 3)
# SourceImage (2048, 1409, 3)
# image_data shape (32, 32)
# SourceImage (640, 640, 3)
# image_data shape (32, 32)
# SourceImage (421, 285, 3)
# image_data shape (32, 32)
# SourceImage (255, 340, 3)
# image_data shape (32, 32)
# SourceImage (3264, 2448, 3)
# SourceImage (694, 700, 3)
# SourceImage (211, 316, 3)
# image_data shape (32, 32)
# SourceImage (607, 300, 3)
# SourceImage (266, 400, 3)
# SourceImage (645, 635, 3)
# image_data shape (32, 32)
# SourceImage (618, 468, 3)
# SourceImage (240, 320, 3)
# SourceImage (450, 800, 3)
# image_data shape (32, 32)
# SourceImage (675, 1200, 3)
# image_data shape (32, 32)
# SourceImage (3264, 2024, 3)
# image_data shape (32, 32)
# SourceImage (640, 640, 3)
# image_data shape (32, 32)
# SourceImage (400, 276, 3)
# SourceImage (500, 500, 3)
# image_data shape (32, 32)
# SourceImage (900, 900, 3)
# SourceImage (210, 210, 3)
# SourceImage (360, 300, 3)
# image_data shape (32, 32)
# SourceImage (1024, 1024, 3)
# SourceImage (1030, 654, 3)
# SourceImage (900, 600, 3)
# image_data shape (32, 32)
# SourceImage (870, 900, 3)
# SourceImage (360, 480, 3)
# Full dataset tensor: (227, 32, 32)
# Mean: 0.448002
# Standard deviation: 0.272736
# Pickling emotion-recognition/3.pickle.
# emotion-recognition/3
# SourceImage (576, 586, 3)
# SourceImage (582, 638, 3)
# image_data shape (32, 32)
# SourceImage (923, 1223, 3)
# SourceImage (516, 490, 3)
# image_data shape (32, 32)
# SourceImage (1430, 1142, 3)
# image_data shape (32, 32)
# SourceImage (530, 353, 3)
# image_data shape (32, 32)
# SourceImage (768, 1024, 3)
# SourceImage (1067, 1600, 3)
# image_data shape (32, 32)
# SourceImage (480, 640, 3)
# SourceImage (333, 500, 3)
# image_data shape (32, 32)
# SourceImage (936, 1024, 3)
# image_data shape (32, 32)
# SourceImage (1920, 1271, 3)
# image_data shape (32, 32)
# SourceImage (1024, 803, 3)
# image_data shape (32, 32)
# SourceImage (3337, 5000, 3)
# image_data shape (32, 32)
# SourceImage (500, 500, 3)
# SourceImage (680, 1024, 3)
# SourceImage (530, 354, 3)
# SourceImage (200, 200, 3)
# image_data shape (32, 32)
# SourceImage (425, 524, 3)
# SourceImage (1200, 1600, 3)
# SourceImage (683, 1024, 3)
# Full dataset tensor: (11, 32, 32)
# Mean: 0.580185
# Standard deviation: 0.251126
# Pickling emotion-recognition/4.pickle.
# emotion-recognition/4
# SourceImage (768, 960, 3)
# SourceImage (1205, 900, 3)
# image_data shape (32, 32)
# SourceImage (848, 566, 3)
# image_data shape (32, 32)
# SourceImage (799, 796, 3)
# image_data shape (32, 32)
# SourceImage (600, 750, 3)
# image_data shape (32, 32)
# SourceImage (750, 600, 3)
# image_data shape (32, 32)
# Full dataset tensor: (5, 32, 32)
# Mean: 0.488343
# Standard deviation: 0.30744
# Pickling emotion-recognition/5.pickle.
# emotion-recognition/5
# SourceImage (473, 600, 3)
# SourceImage (382, 532, 3)
# SourceImage (960, 1280, 3)
# SourceImage (522, 337, 3)
# image_data shape (32, 32)
# SourceImage (271, 241, 3)
# image_data shape (32, 32)
# SourceImage (1452, 900, 3)
# image_data shape (32, 32)
# SourceImage (640, 637, 3)
# image_data shape (32, 32)
# SourceImage (333, 500, 3)
# image_data shape (32, 32)
# SourceImage (720, 600, 3)
# SourceImage (809, 1210, 3)
# image_data shape (32, 32)
# SourceImage (1178, 1000, 3)
# image_data shape (32, 32)
# SourceImage (768, 1024, 3)
# image_data shape (32, 32)
# SourceImage (768, 1024, 3)
# SourceImage (1300, 957, 3)
# image_data shape (32, 32)
# SourceImage (250, 250, 3)
# image_data shape (32, 32)
# SourceImage (1024, 1280, 3)
# image_data shape (32, 32)
# SourceImage (581, 708, 3)
# SourceImage (700, 467, 3)
# SourceImage (523, 327, 3)
# SourceImage (1065, 1300, 3)
# image_data shape (32, 32)
# SourceImage (399, 266, 3)
# Full dataset tensor: (12, 32, 32)
# Mean: 0.519612
# Standard deviation: 0.23407
# Pickling emotion-recognition/6.pickle.
# emotion-recognition/6
# SourceImage (178, 178, 3)
# image_data shape (32, 32)
# SourceImage (300, 450, 3)
# image_data shape (32, 32)
# SourceImage (200, 130, 3)
# image_data shape (32, 32)
# SourceImage (800, 571, 3)
# image_data shape (32, 32)
# SourceImage (900, 707, 3)
# SourceImage (1300, 953, 3)
# image_data shape (32, 32)
# SourceImage (480, 720, 3)
# image_data shape (32, 32)
# SourceImage (640, 480, 3)
# image_data shape (32, 32)
# SourceImage (300, 240, 3)
# image_data shape (32, 32)
# SourceImage (640, 480, 3)
# image_data shape (32, 32)
# SourceImage (500, 500, 3)
# image_data shape (32, 32)
# SourceImage (786, 550, 3)
# image_data shape (32, 32)
# SourceImage (254, 216, 3)
# image_data shape (32, 32)
# SourceImage (240, 320, 3)
# SourceImage (385, 400, 3)
# SourceImage (100, 100, 3)
# image_data shape (32, 32)
# SourceImage (748, 600, 3)
# image_data shape (32, 32)
# SourceImage (1300, 957, 3)
# image_data shape (32, 32)
# SourceImage (798, 1200, 3)
# image_data shape (32, 32)
# SourceImage (1600, 1200, 3)
# image_data shape (32, 32)
# SourceImage (280, 180, 3)
# image_data shape (32, 32)
# SourceImage (262, 198, 3)
# SourceImage (470, 450, 3)
# image_data shape (32, 32)
# SourceImage (680, 600, 3)
# image_data shape (32, 32)
# SourceImage (953, 630, 3)
# SourceImage (100, 100, 3)
# image_data shape (32, 32)
# SourceImage (2400, 1590, 3)
# image_data shape (32, 32)
# SourceImage (1536, 1024, 3)
# image_data shape (32, 32)
# SourceImage (579, 600, 3)
# SourceImage (293, 400, 3)
# image_data shape (32, 32)
# SourceImage (900, 602, 3)
# SourceImage (1500, 1500, 3)
# image_data shape (32, 32)
# SourceImage (800, 533, 3)
# image_data shape (32, 32)
# SourceImage (470, 450, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# image_data shape (32, 32)
# SourceImage (225, 300, 3)
# image_data shape (32, 32)
# SourceImage (1000, 671, 3)
# image_data shape (32, 32)
# SourceImage (360, 480, 3)
# image_data shape (32, 32)
# SourceImage (599, 596, 3)
# image_data shape (32, 32)
# SourceImage (756, 580, 3)
# image_data shape (32, 32)
# SourceImage (200, 180, 3)
# SourceImage (320, 240, 3)
# image_data shape (32, 32)
# SourceImage (389, 449, 3)
# SourceImage (600, 480, 3)
# image_data shape (32, 32)
# SourceImage (300, 560, 3)
# SourceImage (480, 507, 3)
# image_data shape (32, 32)
# SourceImage (1333, 1000, 3)
# SourceImage (800, 800, 3)
# image_data shape (32, 32)
# SourceImage (579, 600, 3)
# image_data shape (32, 32)
# SourceImage (1392, 930, 3)
# image_data shape (32, 32)
# SourceImage (469, 500, 3)
# image_data shape (32, 32)
# SourceImage (848, 566, 3)
# image_data shape (32, 32)
# SourceImage (510, 457, 3)
# image_data shape (32, 32)
# SourceImage (1000, 700, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# SourceImage (1024, 1024, 3)
# image_data shape (32, 32)
# SourceImage (330, 330, 3)
# SourceImage (600, 800, 3)
# image_data shape (32, 32)
# SourceImage (587, 896, 3)
# image_data shape (32, 32)
# SourceImage (1000, 763, 3)
# image_data shape (32, 32)
# SourceImage (1056, 700, 3)
# SourceImage (567, 451, 3)
# image_data shape (32, 32)
# SourceImage (200, 240, 3)
# image_data shape (32, 32)
# SourceImage (720, 1280, 3)
# SourceImage (360, 251, 3)
# image_data shape (32, 32)
# SourceImage (1222, 898, 3)
# image_data shape (32, 32)
# SourceImage (1152, 2048, 3)
# SourceImage (383, 287, 3)
# image_data shape (32, 32)
# SourceImage (150, 150, 3)
# image_data shape (32, 32)
# SourceImage (108, 100, 3)
# image_data shape (32, 32)
# SourceImage (300, 400, 3)
# image_data shape (32, 32)
# SourceImage (526, 800, 3)
# image_data shape (32, 32)
# SourceImage (395, 304, 3)
# image_data shape (32, 32)
# SourceImage (374, 319, 3)
# image_data shape (32, 32)
# SourceImage (318, 450, 3)
# SourceImage (774, 800, 3)
# image_data shape (32, 32)
# SourceImage (400, 400, 3)
# SourceImage (450, 600, 3)
# image_data shape (32, 32)
# SourceImage (317, 420, 3)
# image_data shape (32, 32)
# SourceImage (700, 467, 3)
# image_data shape (32, 32)
# SourceImage (821, 800, 3)
# image_data shape (32, 32)
# SourceImage (1600, 1200, 3)
# image_data shape (32, 32)
# SourceImage (159, 116, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# SourceImage (1032, 774, 3)
# image_data shape (32, 32)
# SourceImage (974, 1023, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# image_data shape (32, 32)
# SourceImage (644, 568, 3)
# image_data shape (32, 32)
# SourceImage (2585, 1899, 3)
# image_data shape (32, 32)
# SourceImage (360, 360, 3)
# image_data shape (32, 32)
# SourceImage (100, 100, 3)
# SourceImage (454, 411, 3)
# SourceImage (306, 306, 3)
# image_data shape (32, 32)
# SourceImage (300, 400, 3)
# SourceImage (800, 566, 3)
# SourceImage (1600, 1156, 3)
# SourceImage (1300, 974, 3)
# image_data shape (32, 32)
# SourceImage (500, 500, 3)
# image_data shape (32, 32)
# SourceImage (189, 152, 3)
# image_data shape (32, 32)
# SourceImage (800, 533, 3)
# image_data shape (32, 32)
# SourceImage (1150, 860, 3)
# image_data shape (32, 32)
# Full dataset tensor: (77, 32, 32)
# Mean: 0.522184
# Standard deviation: 0.257347

# %%
# first load the pickle file, loading one for illustration purpose
t = pickle.load(open("emotion-recognition/4.pickle", "r"))
# need to use matplotlib inline if want to show at jupyter Notebook
# %matplotlib inline
# plot one of image. the number 5 to be exactly
plt.imshow(t[3], interpolation='nearest')
# show the image
plt.show()
