# %% [markdown]
# Explanation of this code
#
# http://www.paulvangent.com/2016/04/01/emotion-recognition-with-python-opencv-and-a-face-dataset/

# %% [markdown]
# # Dataset: CK+, Jaffe, Rafd + Crawling Data

# %% [markdown]
# # 1. Organising the dataset

# %%
import os
os.getcwd()
# Out:
# '/Users/ryan/git_ryan/emotion_recognitoin'

# %%
from shutil import copyfile
import glob

emotions = ["neutral", "anger", "contempt", "disgust", "fear", "happy", "sadness", "surprise"] #Define emotion order
participants = glob.glob("source_emotion/*") #Returns a list of all folders with participant numbers

#Create folders

for x in participants:
    part = "%s" %x[-4:] #store current participant number
    for sessions in glob.glob("%s/*" %x): #Store list of sessions for current participant
        for files in glob.glob("%s/*" %sessions):
            current_session = files[20:-30]
            file = open(files, 'r')
            
            emotion = int(float(file.readline())) #emotions are encoded as a float, readline as float, then convert to integer.
            
            sourcefile_emotion = glob.glob("source_images/%s/%s/*" %(part, current_session))[-1] #get path for last image in sequence, which contains the emotion
            sourcefile_neutral = glob.glob("source_images/%s/%s/*" %(part, current_session))[0] #do same for neutral image
            
            dest_neut = "sorted_set/neutral/%s" %sourcefile_neutral[25:] #Generate path to put neutral image
            dest_emot = "sorted_set/%s/%s" %(emotions[emotion], sourcefile_emotion[25:]) #Do same for emotion containing image
            
            copyfile(sourcefile_neutral, dest_neut) #Copy file
            copyfile(sourcefile_emotion, dest_emot) #Copy file

# %% [markdown]
# # 2. Extracting faces

# %%
import glob
import cv2

faceDet = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
faceDet2 = cv2.CascadeClassifier("haarcascade_frontalface_alt2.xml")
faceDet3 = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
faceDet4 = cv2.CascadeClassifier("haarcascade_frontalface_alt_tree.xml")

emotions = ["neutral", "anger", "contempt", "disgust", "fear", "happy", "sadness", "surprise"] #Define emotions

# %%
files = glob.glob("sorted_set/%s/*" %emotion)
files
# Out:
# []

# %%
def detect_faces(emotion):
    files = glob.glob("sorted_set/%s/*" %emotion) #Get list of all images with emotion
    filenumber = 0
    for f in files:
        frame = cv2.imread(f) #Open image
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) #Convert image to grayscale
        
        #Detect face using 4 different classifiers
        face = faceDet.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
        face2 = faceDet2.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
        face3 = faceDet3.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
        face4 = faceDet4.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)

        #Go over detected faces, stop at first detected face, return empty if no face.
        if len(face) == 1:
            facefeatures = face
        elif len(face2) == 1:
            facefeatures == face2
        elif len(face3) == 1:
            facefeatures = face3
        elif len(face4) == 1:
            facefeatures = face4
        else:
            facefeatures = ""
        
        #Cut and save face
        for (x, y, w, h) in facefeatures: #get coordinates and size of rectangle containing face
            print "face found in file: %s" %f
            gray = gray[y:y+h, x:x+w] #Cut the frame to size
            
            try:
                out = cv2.resize(gray, (350, 350)) #Resize face so all images have same size
                cv2.imwrite("dataset/%s/%s.jpg" %(emotion, filenumber), out) #Write image
            except:
               pass #If error, pass file
        filenumber += 1 #Increment image number

for emotion in emotions: 
    detect_faces(emotion) #Call functiona
# Out:
# face found in file: sorted_set/neutral/00_002_00000001.png
# face found in file: sorted_set/neutral/00_005_00000001.png
# face found in file: sorted_set/neutral/00_006_00000001.png
# face found in file: sorted_set/neutral/01_001_00000001.png
# face found in file: sorted_set/neutral/01_002_00000001.png
# face found in file: sorted_set/neutral/01_004_00000001.png
# face found in file: sorted_set/neutral/01_006_00000001.png
# face found in file: sorted_set/neutral/02_001_00000001.png
# face found in file: sorted_set/neutral/02_002_00000001.png
# face found in file: sorted_set/neutral/02_003_00000001.png
# face found in file: sorted_set/neutral/02_004_00000001.png
# face found in file: sorted_set/neutral/02_009_00000001.png
# face found in file: sorted_set/neutral/03_001_00000001.png
# face found in file: sorted_set/neutral/03_002_00000001.png
# face found in file: sorted_set/neutral/03_006_00000001.png
# face found in file: sorted_set/neutral/04_001_00000001.png
# face found in file: sorted_set/neutral/04_002_00000001.png
# face found in file: sorted_set/neutral/04_004_00000001.png
# face found in file: sorted_set/neutral/04_006_00000001.png
# face found in file: sorted_set/neutral/05_001_00000001.png
# face found in file: sorted_set/neutral/05_002_00000001.png
# face found in file: sorted_set/neutral/05_006_00000001.png
# face found in file: sorted_set/neutral/05_008_00000001.png
# face found in file: sorted_set/neutral/06_001_00000001.png
# face found in file: sorted_set/neutral/06_002_00000001.png
# face found in file: sorted_set/neutral/06_004_00000001.png
# face found in file: sorted_set/neutral/06_006_00000001.png
# face found in file: sorted_set/neutral/07_001_00000001.png
# face found in file: sorted_set/neutral/07_005_00000001.png
# face found in file: sorted_set/neutral/08_005_00000001.png
# face found in file: sorted_set/neutral/08_006_00000001.png
# face found in file: sorted_set/neutral/08_008_00000001.png
# face found in file: sorted_set/neutral/09_003_00000001.png
# face found in file: sorted_set/neutral/09_005_00000001.png
# face found in file: sorted_set/neutral/09_006_00000001.png
# face found in file: sorted_set/neutral/10_001_00000001.png
# face found in file: sorted_set/neutral/10_002_00000001.png
# face found in file: sorted_set/neutral/10_004_00000001.png
# face found in file: sorted_set/neutral/10_006_00000001.png
# face found in file: sorted_set/neutral/11_001_00000001.png
# face found in file: sorted_set/neutral/11_002_00000001.png
# face found in file: sorted_set/neutral/11_003_00000001.png
# face found in file: sorted_set/neutral/11_004_00000001.png
# face found in file: sorted_set/neutral/11_005_00000001.png
# face found in file: sorted_set/neutral/11_006_00000001.png
# face found in file: sorted_set/neutral/11_007_00000001.png
# face found in file: sorted_set/neutral/12_005_00000001.png
# face found in file: sorted_set/neutral/13_001_00000001.png
# face found in file: sorted_set/neutral/13_003_00000001.png
# face found in file: sorted_set/neutral/13_008_00000001.png
# face found in file: sorted_set/neutral/14_001_00000001.png
# face found in file: sorted_set/neutral/14_002_00000001.png
# face found in file: sorted_set/neutral/14_003_00000001.png
# face found in file: sorted_set/neutral/14_005_00000001.png
# face found in file: sorted_set/neutral/14_006_00000001.png
# face found in file: sorted_set/neutral/15_001_00000001.png
# face found in file: sorted_set/neutral/15_004_00000001.png
# face found in file: sorted_set/neutral/15_008_00000001.png
# face found in file: sorted_set/neutral/16_001_00000001.png
# face found in file: sorted_set/neutral/16_006_00000001.png
# face found in file: sorted_set/neutral/16_007_00000001.png
# face found in file: sorted_set/neutral/17_001_00000001.png
# face found in file: sorted_set/neutral/17_003_00000001.png
# face found in file: sorted_set/neutral/17_006_00000001.png
# face found in file: sorted_set/neutral/19_001_00000001.png
# face found in file: sorted_set/neutral/19_003_00000001.png
# face found in file: sorted_set/neutral/19_008_00000001.png
# face found in file: sorted_set/neutral/22_001_00000001.png
# face found in file: sorted_set/neutral/22_005_00000001.png
# face found in file: sorted_set/neutral/22_006_00000001.png
# face found in file: sorted_set/neutral/24_001_00000001.png
# face found in file: sorted_set/neutral/24_003_00000001.png
# face found in file: sorted_set/neutral/24_006_00000001.png
# face found in file: sorted_set/neutral/24_007_00000001.png
# face found in file: sorted_set/neutral/25_001_00000001.png
# face found in file: sorted_set/neutral/25_005_00000001.png
# face found in file: sorted_set/neutral/25_006_00000001.png
# face found in file: sorted_set/neutral/25_007_00000001.png
# face found in file: sorted_set/neutral/25_008_00000001.png
# face found in file: sorted_set/neutral/26_001_00000001.png
# face found in file: sorted_set/neutral/26_002_00000001.png
# face found in file: sorted_set/neutral/26_003_00000001.png
# face found in file: sorted_set/neutral/26_004_00000001.png
# face found in file: sorted_set/neutral/26_006_00000001.png
# face found in file: sorted_set/neutral/26_008_00000001.png
# face found in file: sorted_set/neutral/27_001_00000001.png
# face found in file: sorted_set/neutral/27_004_00000001.png
# face found in file: sorted_set/neutral/27_010_00000001.png
# face found in file: sorted_set/neutral/28_001_00000001.png
# face found in file: sorted_set/neutral/28_004_00000001.png
# face found in file: sorted_set/neutral/28_011_00000001.png
# face found in file: sorted_set/neutral/29_001_00000001.png
# face found in file: sorted_set/neutral/29_002_00000001.png
# face found in file: sorted_set/neutral/29_006_00000001.png
# face found in file: sorted_set/neutral/29_011_00000001.png
# face found in file: sorted_set/neutral/29_012_00000001.png
# face found in file: sorted_set/neutral/30_001_00000001.png
# face found in file: sorted_set/neutral/30_007_00000001.png
# face found in file: sorted_set/neutral/30_009_00000001.png
# face found in file: sorted_set/neutral/30_012_00000001.png
# face found in file: sorted_set/neutral/30_013_00000001.png
# face found in file: sorted_set/neutral/31_001_00000001.png
# face found in file: sorted_set/neutral/31_003_00000001.png
# face found in file: sorted_set/neutral/31_006_00000001.png
# face found in file: sorted_set/neutral/31_010_00000001.png
# face found in file: sorted_set/neutral/32_001_00000001.png
# face found in file: sorted_set/neutral/32_002_00000001.png
# face found in file: sorted_set/neutral/32_003_00000001.png
# face found in file: sorted_set/neutral/32_004_00000001.png
# face found in file: sorted_set/neutral/32_005_00000001.png
# face found in file: sorted_set/neutral/32_006_00000001.png
# face found in file: sorted_set/neutral/32_008_00000001.png
# face found in file: sorted_set/neutral/33_003_00000001.png
# face found in file: sorted_set/neutral/33_009_00000001.png
# face found in file: sorted_set/neutral/33_010_00000001.png
# face found in file: sorted_set/neutral/34_001_00000001.png
# face found in file: sorted_set/neutral/34_003_00000001.png
# face found in file: sorted_set/neutral/34_004_00000001.png
# face found in file: sorted_set/neutral/34_005_00000001.png
# face found in file: sorted_set/neutral/34_008_00000001.png
# face found in file: sorted_set/neutral/35_001_00000001.png
# face found in file: sorted_set/neutral/35_005_00000001.png
# face found in file: sorted_set/neutral/35_006_00000001.png
# face found in file: sorted_set/neutral/35_012_00000001.png
# face found in file: sorted_set/neutral/36_001_00000001.png
# face found in file: sorted_set/neutral/36_003_00000001.png
# face found in file: sorted_set/neutral/36_005_00000001.png
# face found in file: sorted_set/neutral/36_006_00000001.png
# face found in file: sorted_set/neutral/37_001_00000001.png
# face found in file: sorted_set/neutral/37_003_00000001.png
# face found in file: sorted_set/neutral/37_005_00000001.png
# face found in file: sorted_set/neutral/37_006_00000001.png
# face found in file: sorted_set/neutral/37_011_00000001.png
# face found in file: sorted_set/neutral/38_001_00000001.png
# face found in file: sorted_set/neutral/38_004_00000001.png
# face found in file: sorted_set/neutral/38_005_00000001.png
# face found in file: sorted_set/neutral/38_007_00000001.png
# face found in file: sorted_set/neutral/38_008_00000001.png
# face found in file: sorted_set/neutral/39_002_00000001.png
# face found in file: sorted_set/neutral/42_001_00000001.png
# face found in file: sorted_set/neutral/42_002_00000001.png
# face found in file: sorted_set/neutral/42_004_00000001.png
# face found in file: sorted_set/neutral/42_006_00000001.png
# face found in file: sorted_set/neutral/44_001_00000001.png
# face found in file: sorted_set/neutral/44_003_00000001.png
# face found in file: sorted_set/neutral/44_006_00000001.png
# face found in file: sorted_set/neutral/45_004_00000001.png
# face found in file: sorted_set/neutral/45_005_00000001.png
# face found in file: sorted_set/neutral/46_001_00000001.png
# face found in file: sorted_set/neutral/46_002_00000001.png
# face found in file: sorted_set/neutral/46_003_00000001.png
# face found in file: sorted_set/neutral/46_004_00000001.png
# face found in file: sorted_set/neutral/47_002_00000001.png
# face found in file: sorted_set/neutral/48_002_00000001.png
# face found in file: sorted_set/neutral/49_002_00000001.png
# face found in file: sorted_set/neutral/50_001_00000001.png
# face found in file: sorted_set/neutral/50_002_00000001.png
# face found in file: sorted_set/neutral/50_004_00000001.png
# face found in file: sorted_set/neutral/50_006_00000001.png
# face found in file: sorted_set/neutral/51_002_00000001.png
# face found in file: sorted_set/neutral/51_003_00000001.png
# face found in file: sorted_set/neutral/52_001_00000001.png
# face found in file: sorted_set/neutral/52_004_00000001.png
# face found in file: sorted_set/neutral/52_006_00000001.png
# face found in file: sorted_set/neutral/53_001_00000001.png
# face found in file: sorted_set/neutral/53_004_00000001.png
# face found in file: sorted_set/neutral/54_002_00000001.png
# face found in file: sorted_set/neutral/54_003_00000001.png
# face found in file: sorted_set/neutral/54_004_00000001.png
# face found in file: sorted_set/neutral/55_001_00000001.png
# face found in file: sorted_set/neutral/55_002_00000001.png
# face found in file: sorted_set/neutral/55_003_00000001.png
# face found in file: sorted_set/neutral/55_004_00000001.png
# face found in file: sorted_set/neutral/55_005_00000001.png
# face found in file: sorted_set/neutral/55_006_00000001.png
# face found in file: sorted_set/neutral/56_002_00000001.png
# face found in file: sorted_set/neutral/56_003_00000001.png
# face found in file: sorted_set/neutral/56_004_00000001.png
# face found in file: sorted_set/neutral/57_001_00000001.png
# face found in file: sorted_set/neutral/57_002_00000001.png
# face found in file: sorted_set/neutral/57_003_00000001.png
# face found in file: sorted_set/neutral/57_006_00000001.png
# face found in file: sorted_set/neutral/58_001_00000001.png
# face found in file: sorted_set/neutral/58_002_00000001.png
# face found in file: sorted_set/neutral/58_005_00000001.png
# face found in file: sorted_set/neutral/58_006_00000001.png
# face found in file: sorted_set/neutral/59_001_00000001.png
# face found in file: sorted_set/neutral/59_002_00000001.png
# face found in file: sorted_set/neutral/60_002_00000001.png
# face found in file: sorted_set/neutral/60_003_00000001.png
# face found in file: sorted_set/neutral/60_005_00000001.png
# face found in file: sorted_set/neutral/60_006_00000001.png
# face found in file: sorted_set/neutral/61_001_00000001.png
# face found in file: sorted_set/neutral/61_002_00000001.png
# face found in file: sorted_set/neutral/61_004_00000001.png
# face found in file: sorted_set/neutral/62_001_00000001.png
# face found in file: sorted_set/neutral/62_002_00000001.png
# face found in file: sorted_set/neutral/62_004_00000001.png
# face found in file: sorted_set/neutral/62_005_00000001.png
# face found in file: sorted_set/neutral/63_001_00000001.png
# face found in file: sorted_set/neutral/63_002_00000001.png
# face found in file: sorted_set/neutral/64_001_00000001.png
# face found in file: sorted_set/neutral/64_003_00000001.png
# face found in file: sorted_set/neutral/64_004_00000001.png
# face found in file: sorted_set/neutral/65_002_00000001.png
# face found in file: sorted_set/neutral/65_003_00000001.png
# face found in file: sorted_set/neutral/65_004_00000001.png
# face found in file: sorted_set/neutral/65_005_00000001.png
# face found in file: sorted_set/neutral/66_002_00000001.png
# face found in file: sorted_set/neutral/66_003_00000001.png
# face found in file: sorted_set/neutral/66_004_00000001.png
# face found in file: sorted_set/neutral/66_005_00000001.png
# face found in file: sorted_set/neutral/67_002_00000001.png
# face found in file: sorted_set/neutral/67_004_00000001.png
# face found in file: sorted_set/neutral/67_005_00000001.png
# face found in file: sorted_set/neutral/67_006_00000001.png
# face found in file: sorted_set/neutral/68_002_00000001.png
# face found in file: sorted_set/neutral/68_003_00000001.png
# face found in file: sorted_set/neutral/68_004_00000001.png
# face found in file: sorted_set/neutral/68_005_00000001.png
# face found in file: sorted_set/neutral/69_002_00000001.png
# face found in file: sorted_set/neutral/69_003_00000001.png
# face found in file: sorted_set/neutral/69_004_00000001.png
# face found in file: sorted_set/neutral/70_002_00000001.png
# face found in file: sorted_set/neutral/70_003_00000001.png
# face found in file: sorted_set/neutral/70_005_00000001.png
# face found in file: sorted_set/neutral/71_001_00000001.png
# face found in file: sorted_set/neutral/71_002_00000001.png
# face found in file: sorted_set/neutral/71_004_00000001.png
# face found in file: sorted_set/neutral/71_005_00000001.png
# face found in file: sorted_set/neutral/71_006_00000001.png
# face found in file: sorted_set/neutral/72_005_00000001.png
# face found in file: sorted_set/neutral/72_006_00000001.png
# face found in file: sorted_set/neutral/73_001_00000001.png
# face found in file: sorted_set/neutral/73_006_00000001.png
# face found in file: sorted_set/neutral/74_001_00000001.png
# face found in file: sorted_set/neutral/74_002_00000001.png
# face found in file: sorted_set/neutral/74_004_00000001.png
# face found in file: sorted_set/neutral/74_005_00000001.png
# face found in file: sorted_set/neutral/75_002_00000001.png
# face found in file: sorted_set/neutral/75_005_00000001.png
# face found in file: sorted_set/neutral/75_006_00000001.png
# face found in file: sorted_set/neutral/75_008_00000001.png
# face found in file: sorted_set/neutral/76_001_00000001.png
# face found in file: sorted_set/neutral/76_005_00000001.png
# face found in file: sorted_set/neutral/76_006_00000001.png
# face found in file: sorted_set/neutral/77_001_00000001.png
# face found in file: sorted_set/neutral/77_006_00000001.png
# face found in file: sorted_set/neutral/78_001_00000001.png
# face found in file: sorted_set/neutral/78_004_00000001.png
# face found in file: sorted_set/neutral/78_007_00000001.png
# face found in file: sorted_set/neutral/79_001_00000001.png
# face found in file: sorted_set/neutral/79_002_00000001.png
# face found in file: sorted_set/neutral/79_004_00000001.png
# face found in file: sorted_set/neutral/80_001_00000001.png
# face found in file: sorted_set/neutral/80_005_00000001.png
# face found in file: sorted_set/neutral/80_008_00000001.png
# face found in file: sorted_set/neutral/81_001_00000001.png
# face found in file: sorted_set/neutral/81_002_00000001.png
# face found in file: sorted_set/neutral/81_008_00000001.png
# face found in file: sorted_set/neutral/82_001_00000001.png
# face found in file: sorted_set/neutral/82_005_00000001.png
# face found in file: sorted_set/neutral/82_007_00000001.png
# face found in file: sorted_set/neutral/83_003_00000001.png
# face found in file: sorted_set/neutral/84_001_00000001.png
# face found in file: sorted_set/neutral/84_002_00000001.png
# face found in file: sorted_set/neutral/85_002_00000001.png
# face found in file: sorted_set/neutral/85_003_00000001.png
# face found in file: sorted_set/neutral/85_004_00000001.png
# face found in file: sorted_set/neutral/86_001_00000001.png
# face found in file: sorted_set/neutral/86_002_00000001.png
# face found in file: sorted_set/neutral/87_001_00000001.png
# face found in file: sorted_set/neutral/87_004_00000001.png
# face found in file: sorted_set/neutral/87_005_00000001.png
# face found in file: sorted_set/neutral/87_007_00000001.png
# face found in file: sorted_set/neutral/88_001_00000001.png
# face found in file: sorted_set/neutral/88_004_00000001.png
# face found in file: sorted_set/neutral/89_001_00000001.png
# face found in file: sorted_set/neutral/89_002_00000001.png
# face found in file: sorted_set/neutral/89_003_00000001.png
# face found in file: sorted_set/neutral/90_002_00000001.png
# face found in file: sorted_set/neutral/90_006_00000001.png
# face found in file: sorted_set/neutral/90_007_00000001.png
# face found in file: sorted_set/neutral/91_001_00000001.png
# face found in file: sorted_set/neutral/91_003_00000001.png
# face found in file: sorted_set/neutral/92_001_00000001.png
# face found in file: sorted_set/neutral/92_003_00000001.png
# face found in file: sorted_set/neutral/92_004_00000001.png
# face found in file: sorted_set/neutral/93_001_00000001.png
# face found in file: sorted_set/neutral/93_004_00000001.png
# face found in file: sorted_set/neutral/94_001_00000001.png
# face found in file: sorted_set/neutral/94_004_00000001.png
# face found in file: sorted_set/neutral/95_001_00000001.png
# face found in file: sorted_set/neutral/95_002_00000001.png
# face found in file: sorted_set/neutral/95_006_00000001.png
# face found in file: sorted_set/neutral/95_007_00000001.png
# face found in file: sorted_set/neutral/95_010_00000001.png
# face found in file: sorted_set/neutral/96_001_00000001.png
# face found in file: sorted_set/neutral/96_003_00000001.png
# face found in file: sorted_set/neutral/96_004_00000001.png
# face found in file: sorted_set/neutral/97_001_00000001.png
# face found in file: sorted_set/neutral/97_004_00000001.png
# face found in file: sorted_set/neutral/97_006_00000001.png
# face found in file: sorted_set/neutral/98_003_00000001.png
# face found in file: sorted_set/neutral/98_004_00000001.png
# face found in file: sorted_set/neutral/99_001_00000001.png
# face found in file: sorted_set/neutral/99_003_00000001.png
# face found in file: sorted_set/neutral/99_004_00000001.png
# face found in file: sorted_set/neutral/99_007_00000001.png
# face found in file: sorted_set/anger/00_005_00000023.png
# face found in file: sorted_set/anger/01_001_00000067.png
# face found in file: sorted_set/anger/02_001_00000016.png
# face found in file: sorted_set/anger/03_001_00000071.png
# face found in file: sorted_set/anger/04_001_00000022.png
# face found in file: sorted_set/anger/06_001_00000040.png
# face found in file: sorted_set/anger/09_003_00000017.png
# face found in file: sorted_set/anger/10_004_00000019.png
# face found in file: sorted_set/anger/11_004_00000021.png
# face found in file: sorted_set/anger/11_006_00000010.png
# face found in file: sorted_set/anger/12_005_00000017.png
# face found in file: sorted_set/anger/13_008_00000023.png
# face found in file: sorted_set/anger/14_003_00000030.png
# face found in file: sorted_set/anger/17_006_00000010.png
# face found in file: sorted_set/anger/19_008_00000018.png
# face found in file: sorted_set/anger/22_005_00000032.png
# face found in file: sorted_set/anger/26_003_00000015.png
# face found in file: sorted_set/anger/26_008_00000029.png
# face found in file: sorted_set/anger/27_010_00000018.png
# face found in file: sorted_set/anger/28_001_00000024.png
# face found in file: sorted_set/anger/29_001_00000019.png
# face found in file: sorted_set/anger/29_006_00000010.png
# face found in file: sorted_set/anger/30_007_00000020.png
# face found in file: sorted_set/anger/32_003_00000017.png
# face found in file: sorted_set/anger/33_003_00000047.png
# face found in file: sorted_set/anger/34_003_00000011.png
# face found in file: sorted_set/anger/34_003_00000027.png
# face found in file: sorted_set/anger/36_005_00000010.png
# face found in file: sorted_set/anger/37_003_00000022.png
# face found in file: sorted_set/anger/42_004_00000020.png
# face found in file: sorted_set/anger/45_005_00000030.png
# face found in file: sorted_set/anger/50_004_00000021.png
# face found in file: sorted_set/anger/55_004_00000028.png
# face found in file: sorted_set/anger/58_005_00000010.png
# face found in file: sorted_set/anger/66_005_00000011.png
# face found in file: sorted_set/anger/67_004_00000023.png
# face found in file: sorted_set/anger/71_004_00000028.png
# face found in file: sorted_set/anger/72_005_00000019.png
# face found in file: sorted_set/anger/75_008_00000012.png
# face found in file: sorted_set/anger/82_005_00000017.png
# face found in file: sorted_set/anger/87_007_00000016.png
# face found in file: sorted_set/anger/89_003_00000036.png
# face found in file: sorted_set/anger/90_007_00000014.png
# face found in file: sorted_set/anger/92_003_00000014.png
# face found in file: sorted_set/anger/99_001_00000018.png
# face found in file: sorted_set/contempt/02_002_00000009.png
# face found in file: sorted_set/contempt/03_002_00000008.png
# face found in file: sorted_set/contempt/04_002_00000009.png
# face found in file: sorted_set/contempt/05_002_00000021.png
# face found in file: sorted_set/contempt/06_002_00000009.png
# face found in file: sorted_set/contempt/38_008_00000009.png
# face found in file: sorted_set/contempt/39_002_00000013.png
# face found in file: sorted_set/contempt/47_002_00000013.png
# face found in file: sorted_set/contempt/48_002_00000015.png
# face found in file: sorted_set/contempt/49_002_00000013.png
# face found in file: sorted_set/contempt/51_002_00000029.png
# face found in file: sorted_set/contempt/54_002_00000013.png
# face found in file: sorted_set/contempt/55_002_00000012.png
# face found in file: sorted_set/contempt/56_002_00000021.png
# face found in file: sorted_set/contempt/57_002_00000011.png
# face found in file: sorted_set/contempt/58_002_00000011.png
# face found in file: sorted_set/contempt/60_006_00000010.png
# face found in file: sorted_set/contempt/95_002_00000007.png
# face found in file: sorted_set/disgust/02_009_00000015.png
# face found in file: sorted_set/disgust/05_001_00000011.png
# face found in file: sorted_set/disgust/05_008_00000010.png
# face found in file: sorted_set/disgust/06_004_00000008.png
# face found in file: sorted_set/disgust/07_005_00000011.png
# face found in file: sorted_set/disgust/08_006_00000020.png
# face found in file: sorted_set/disgust/09_005_00000014.png
# face found in file: sorted_set/disgust/11_005_00000020.png
# face found in file: sorted_set/disgust/11_007_00000014.png
# face found in file: sorted_set/disgust/16_006_00000007.png
# face found in file: sorted_set/disgust/22_006_00000017.png
# face found in file: sorted_set/disgust/24_006_00000011.png
# face found in file: sorted_set/disgust/25_008_00000010.png
# face found in file: sorted_set/disgust/28_004_00000013.png
# face found in file: sorted_set/disgust/29_011_00000018.png
# face found in file: sorted_set/disgust/30_012_00000011.png
# face found in file: sorted_set/disgust/31_010_00000018.png
# face found in file: sorted_set/disgust/32_005_00000016.png
# face found in file: sorted_set/disgust/34_008_00000013.png
# face found in file: sorted_set/disgust/35_005_00000019.png
# face found in file: sorted_set/disgust/44_006_00000019.png
# face found in file: sorted_set/disgust/45_004_00000015.png
# face found in file: sorted_set/disgust/46_004_00000017.png
# face found in file: sorted_set/disgust/51_003_00000018.png
# face found in file: sorted_set/disgust/52_006_00000013.png
# face found in file: sorted_set/disgust/54_004_00000024.png
# face found in file: sorted_set/disgust/55_003_00000009.png
# face found in file: sorted_set/disgust/56_002_00000010.png
# face found in file: sorted_set/disgust/57_003_00000015.png
# face found in file: sorted_set/disgust/58_006_00000018.png
# face found in file: sorted_set/disgust/60_005_00000021.png
# face found in file: sorted_set/disgust/61_004_00000022.png
# face found in file: sorted_set/disgust/62_005_00000029.png
# face found in file: sorted_set/disgust/65_005_00000008.png
# face found in file: sorted_set/disgust/67_006_00000011.png
# face found in file: sorted_set/disgust/68_005_00000021.png
# face found in file: sorted_set/disgust/69_003_00000011.png
# face found in file: sorted_set/disgust/70_005_00000016.png
# face found in file: sorted_set/disgust/71_006_00000014.png
# face found in file: sorted_set/disgust/73_006_00000014.png
# face found in file: sorted_set/disgust/74_004_00000018.png
# face found in file: sorted_set/disgust/75_005_00000012.png
# face found in file: sorted_set/disgust/76_005_00000012.png
# face found in file: sorted_set/disgust/77_006_00000014.png
# face found in file: sorted_set/disgust/78_007_00000013.png
# face found in file: sorted_set/disgust/79_002_00000012.png
# face found in file: sorted_set/disgust/80_008_00000009.png
# face found in file: sorted_set/disgust/81_008_00000011.png
# face found in file: sorted_set/disgust/82_007_00000010.png
# face found in file: sorted_set/disgust/85_004_00000017.png
# face found in file: sorted_set/disgust/87_004_00000012.png
# face found in file: sorted_set/disgust/88_004_00000020.png
# face found in file: sorted_set/disgust/90_006_00000011.png
# face found in file: sorted_set/disgust/95_006_00000013.png
# face found in file: sorted_set/disgust/96_003_00000012.png
# face found in file: sorted_set/disgust/97_004_00000030.png
# face found in file: sorted_set/disgust/98_003_00000013.png
# face found in file: sorted_set/disgust/99_007_00000012.png
# face found in file: sorted_set/fear/01_004_00000056.png
# face found in file: sorted_set/fear/02_003_00000016.png
# face found in file: sorted_set/fear/02_004_00000052.png
# face found in file: sorted_set/fear/04_004_00000015.png
# face found in file: sorted_set/fear/06_004_00000038.png
# face found in file: sorted_set/fear/11_003_00000014.png
# face found in file: sorted_set/fear/17_003_00000014.png
# face found in file: sorted_set/fear/19_003_00000024.png
# face found in file: sorted_set/fear/24_003_00000011.png
# face found in file: sorted_set/fear/25_006_00000022.png
# face found in file: sorted_set/fear/32_003_00000023.png
# face found in file: sorted_set/fear/32_004_00000014.png
# face found in file: sorted_set/fear/38_001_00000012.png
# face found in file: sorted_set/fear/46_003_00000016.png
# face found in file: sorted_set/fear/50_001_00000017.png
# face found in file: sorted_set/fear/54_002_00000015.png
# face found in file: sorted_set/fear/55_006_00000008.png
# face found in file: sorted_set/fear/59_002_00000017.png
# face found in file: sorted_set/fear/62_001_00000017.png
# face found in file: sorted_set/fear/65_002_00000022.png
# face found in file: sorted_set/fear/68_004_00000010.png
# face found in file: sorted_set/fear/74_001_00000020.png
# face found in file: sorted_set/fear/84_002_00000023.png
# face found in file: sorted_set/fear/91_001_00000015.png
# face found in file: sorted_set/fear/99_003_00000055.png
# face found in file: sorted_set/happy/00_006_00000016.png
# face found in file: sorted_set/happy/06_006_00000011.png
# face found in file: sorted_set/happy/08_008_00000013.png
# face found in file: sorted_set/happy/09_006_00000015.png
# face found in file: sorted_set/happy/10_006_00000015.png
# face found in file: sorted_set/happy/11_006_00000013.png
# face found in file: sorted_set/happy/14_005_00000017.png
# face found in file: sorted_set/happy/14_006_00000023.png
# face found in file: sorted_set/happy/15_008_00000017.png
# face found in file: sorted_set/happy/16_007_00000017.png
# face found in file: sorted_set/happy/24_007_00000024.png
# face found in file: sorted_set/happy/25_005_00000013.png
# face found in file: sorted_set/happy/26_006_00000013.png
# face found in file: sorted_set/happy/27_004_00000016.png
# face found in file: sorted_set/happy/28_011_00000016.png
# face found in file: sorted_set/happy/29_012_00000011.png
# face found in file: sorted_set/happy/30_013_00000015.png
# face found in file: sorted_set/happy/31_006_00000022.png
# face found in file: sorted_set/happy/32_006_00000016.png
# face found in file: sorted_set/happy/32_006_00000023.png
# face found in file: sorted_set/happy/33_010_00000014.png
# face found in file: sorted_set/happy/34_004_00000015.png
# face found in file: sorted_set/happy/34_005_00000010.png
# face found in file: sorted_set/happy/35_006_00000018.png
# face found in file: sorted_set/happy/35_012_00000020.png
# face found in file: sorted_set/happy/36_006_00000020.png
# face found in file: sorted_set/happy/37_006_00000021.png
# face found in file: sorted_set/happy/37_011_00000020.png
# face found in file: sorted_set/happy/38_005_00000016.png
# face found in file: sorted_set/happy/42_006_00000017.png
# face found in file: sorted_set/happy/44_003_00000014.png
# face found in file: sorted_set/happy/50_006_00000023.png
# face found in file: sorted_set/happy/52_004_00000033.png
# face found in file: sorted_set/happy/53_004_00000024.png
# face found in file: sorted_set/happy/55_005_00000045.png
# face found in file: sorted_set/happy/56_004_00000020.png
# face found in file: sorted_set/happy/57_006_00000033.png
# face found in file: sorted_set/happy/60_002_00000026.png
# face found in file: sorted_set/happy/61_002_00000015.png
# face found in file: sorted_set/happy/62_004_00000024.png
# face found in file: sorted_set/happy/63_002_00000023.png
# face found in file: sorted_set/happy/64_003_00000025.png
# face found in file: sorted_set/happy/65_004_00000028.png
# face found in file: sorted_set/happy/66_003_00000012.png
# face found in file: sorted_set/happy/67_005_00000022.png
# face found in file: sorted_set/happy/68_002_00000015.png
# face found in file: sorted_set/happy/69_004_00000017.png
# face found in file: sorted_set/happy/70_003_00000017.png
# face found in file: sorted_set/happy/71_005_00000021.png
# face found in file: sorted_set/happy/72_006_00000022.png
# face found in file: sorted_set/happy/74_005_00000043.png
# face found in file: sorted_set/happy/75_006_00000025.png
# face found in file: sorted_set/happy/76_006_00000019.png
# face found in file: sorted_set/happy/78_004_00000027.png
# face found in file: sorted_set/happy/79_004_00000026.png
# face found in file: sorted_set/happy/83_003_00000019.png
# face found in file: sorted_set/happy/85_002_00000014.png
# face found in file: sorted_set/happy/86_002_00000015.png
# face found in file: sorted_set/happy/87_005_00000012.png
# face found in file: sorted_set/happy/89_002_00000021.png
# face found in file: sorted_set/happy/91_003_00000021.png
# face found in file: sorted_set/happy/92_004_00000024.png
# face found in file: sorted_set/happy/93_004_00000016.png
# face found in file: sorted_set/happy/94_004_00000012.png
# face found in file: sorted_set/happy/95_007_00000021.png
# face found in file: sorted_set/happy/96_004_00000011.png
# face found in file: sorted_set/happy/97_006_00000019.png
# face found in file: sorted_set/happy/98_004_00000015.png
# face found in file: sorted_set/happy/99_004_00000015.png
# face found in file: sorted_set/sadness/01_006_00000041.png
# face found in file: sorted_set/sadness/03_006_00000020.png
# face found in file: sorted_set/sadness/04_006_00000018.png
# face found in file: sorted_set/sadness/05_006_00000019.png
# face found in file: sorted_set/sadness/06_002_00000016.png
# face found in file: sorted_set/sadness/06_006_00000042.png
# face found in file: sorted_set/sadness/08_005_00000022.png
# face found in file: sorted_set/sadness/11_002_00000022.png
# face found in file: sorted_set/sadness/13_003_00000015.png
# face found in file: sorted_set/sadness/14_002_00000016.png
# face found in file: sorted_set/sadness/15_004_00000017.png
# face found in file: sorted_set/sadness/25_001_00000014.png
# face found in file: sorted_set/sadness/26_002_00000016.png
# face found in file: sorted_set/sadness/30_009_00000019.png
# face found in file: sorted_set/sadness/31_003_00000024.png
# face found in file: sorted_set/sadness/32_002_00000018.png
# face found in file: sorted_set/sadness/36_003_00000014.png
# face found in file: sorted_set/sadness/37_005_00000027.png
# face found in file: sorted_set/sadness/38_007_00000011.png
# face found in file: sorted_set/sadness/42_002_00000016.png
# face found in file: sorted_set/sadness/46_001_00000025.png
# face found in file: sorted_set/sadness/64_004_00000014.png
# face found in file: sorted_set/sadness/66_004_00000010.png
# face found in file: sorted_set/sadness/71_002_00000020.png
# face found in file: sorted_set/sadness/80_005_00000013.png
# face found in file: sorted_set/sadness/81_002_00000024.png
# face found in file: sorted_set/sadness/93_001_00000020.png
# face found in file: sorted_set/sadness/95_010_00000014.png
# face found in file: sorted_set/surprise/00_002_00000015.png
# face found in file: sorted_set/surprise/01_002_00000019.png
# face found in file: sorted_set/surprise/02_002_00000018.png
# face found in file: sorted_set/surprise/07_001_00000010.png
# face found in file: sorted_set/surprise/10_001_00000013.png
# face found in file: sorted_set/surprise/10_002_00000014.png
# face found in file: sorted_set/surprise/11_001_00000014.png
# face found in file: sorted_set/surprise/11_001_00000016.png
# face found in file: sorted_set/surprise/13_001_00000012.png
# face found in file: sorted_set/surprise/14_001_00000018.png
# face found in file: sorted_set/surprise/14_001_00000029.png
# face found in file: sorted_set/surprise/15_001_00000008.png
# face found in file: sorted_set/surprise/16_001_00000014.png
# face found in file: sorted_set/surprise/17_001_00000014.png
# face found in file: sorted_set/surprise/19_001_00000011.png
# face found in file: sorted_set/surprise/22_001_00000012.png
# face found in file: sorted_set/surprise/22_001_00000030.png
# face found in file: sorted_set/surprise/24_001_00000014.png
# face found in file: sorted_set/surprise/25_007_00000009.png
# face found in file: sorted_set/surprise/26_001_00000015.png
# face found in file: sorted_set/surprise/26_004_00000012.png
# face found in file: sorted_set/surprise/27_001_00000017.png
# face found in file: sorted_set/surprise/29_002_00000011.png
# face found in file: sorted_set/surprise/30_001_00000018.png
# face found in file: sorted_set/surprise/31_001_00000016.png
# face found in file: sorted_set/surprise/32_001_00000022.png
# face found in file: sorted_set/surprise/32_008_00000010.png
# face found in file: sorted_set/surprise/33_009_00000006.png
# face found in file: sorted_set/surprise/34_001_00000029.png
# face found in file: sorted_set/surprise/35_001_00000015.png
# face found in file: sorted_set/surprise/35_001_00000039.png
# face found in file: sorted_set/surprise/36_001_00000019.png
# face found in file: sorted_set/surprise/37_001_00000014.png
# face found in file: sorted_set/surprise/37_001_00000020.png
# face found in file: sorted_set/surprise/38_004_00000013.png
# face found in file: sorted_set/surprise/42_001_00000019.png
# face found in file: sorted_set/surprise/44_001_00000024.png
# face found in file: sorted_set/surprise/46_002_00000006.png
# face found in file: sorted_set/surprise/50_002_00000018.png
# face found in file: sorted_set/surprise/51_002_00000019.png
# face found in file: sorted_set/surprise/52_001_00000015.png
# face found in file: sorted_set/surprise/53_001_00000023.png
# face found in file: sorted_set/surprise/54_003_00000007.png
# face found in file: sorted_set/surprise/55_001_00000012.png
# face found in file: sorted_set/surprise/56_003_00000010.png
# face found in file: sorted_set/surprise/57_001_00000019.png
# face found in file: sorted_set/surprise/58_001_00000020.png
# face found in file: sorted_set/surprise/59_001_00000018.png
# face found in file: sorted_set/surprise/60_003_00000018.png
# face found in file: sorted_set/surprise/61_001_00000012.png
# face found in file: sorted_set/surprise/62_002_00000016.png
# face found in file: sorted_set/surprise/63_001_00000013.png
# face found in file: sorted_set/surprise/64_001_00000012.png
# face found in file: sorted_set/surprise/65_003_00000022.png
# face found in file: sorted_set/surprise/66_002_00000022.png
# face found in file: sorted_set/surprise/67_002_00000014.png
# face found in file: sorted_set/surprise/68_003_00000014.png
# face found in file: sorted_set/surprise/69_002_00000014.png
# face found in file: sorted_set/surprise/70_002_00000016.png
# face found in file: sorted_set/surprise/71_001_00000013.png
# face found in file: sorted_set/surprise/73_001_00000013.png
# face found in file: sorted_set/surprise/74_002_00000016.png
# face found in file: sorted_set/surprise/75_002_00000014.png
# face found in file: sorted_set/surprise/76_001_00000017.png
# face found in file: sorted_set/surprise/77_001_00000028.png
# face found in file: sorted_set/surprise/78_001_00000033.png
# face found in file: sorted_set/surprise/79_001_00000012.png
# face found in file: sorted_set/surprise/80_001_00000018.png
# face found in file: sorted_set/surprise/81_001_00000019.png
# face found in file: sorted_set/surprise/82_001_00000015.png
# face found in file: sorted_set/surprise/84_001_00000010.png
# face found in file: sorted_set/surprise/85_003_00000013.png
# face found in file: sorted_set/surprise/86_001_00000019.png
# face found in file: sorted_set/surprise/87_001_00000011.png
# face found in file: sorted_set/surprise/88_001_00000017.png
# face found in file: sorted_set/surprise/89_001_00000016.png
# face found in file: sorted_set/surprise/90_002_00000011.png
# face found in file: sorted_set/surprise/92_001_00000017.png
# face found in file: sorted_set/surprise/94_001_00000010.png
# face found in file: sorted_set/surprise/95_001_00000016.png
# face found in file: sorted_set/surprise/96_001_00000007.png
# face found in file: sorted_set/surprise/97_001_00000021.png
# face found in file: sorted_set/surprise/99_001_00000014.png

# %% [markdown]
# # 3. Creating the training and classification set

# %%
import cv2
import glob
import random
import numpy as np

emotions = ["neutral", "anger", "contempt", "disgust", "fear", "happy", "sadness", "surprise"] #Emotion list
fishface = cv2.createFisherFaceRecognizer() #Initialize fisher face classifier

# %%
data = {}

def get_files(emotion): #Define function to get file list, randomly shuffle it and split 80/20
    files = glob.glob("dataset/%s/*" %emotion)
    random.shuffle(files)
    training = files[:int(len(files)*0.8)] #get first 80% of file list
    prediction = files[-int(len(files)*0.2):] #get last 20% of file list
    return training, prediction

def make_sets():
    training_data = []
    training_labels = []
    prediction_data = []
    prediction_labels = []
    for emotion in emotions:
        training, prediction = get_files(emotion)
        #Append data to training and prediction list, and generate labels 0-7
        for item in training:
            image = cv2.imread(item) #open image
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #convert to grayscale
            training_data.append(gray) #append image array to training data list
            training_labels.append(emotions.index(emotion))
    
        for item in prediction: #repeat above process for prediction set
            image = cv2.imread(item)
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            prediction_data.append(gray)
            prediction_labels.append(emotions.index(emotion))

    return training_data, training_labels, prediction_data, prediction_labels

def run_recognizer():
    training_data, training_labels, prediction_data, prediction_labels = make_sets()
    
    print "training fisher face classifier"
    print "size of training set is:", len(training_labels), "images"
    fishface.train(training_data, np.asarray(training_labels))

    print "predicting classification set"
    cnt = 0
    correct = 0
    incorrect = 0
    for image in prediction_data:
        pred, conf = fishface.predict(image)
        if pred == prediction_labels[cnt]:
            correct += 1
            cnt += 1
        else:
            incorrect += 1
            cnt += 1
    return ((100*correct)/(correct + incorrect))

#Now run it
metascore = []
for i in range(0,10):
    correct = run_recognizer()
    print "got", correct, "percent correct!"
    metascore.append(correct)

print "\n\nend score:", np.mean(metascore), "percent correct!"
# Out:
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 26 percent correct!
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 16 percent correct!
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 20 percent correct!
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 18 percent correct!
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 26 percent correct!
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 18 percent correct!
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 22 percent correct!
# training fisher face classifier
# size of training set is: 664 images
# predicting classification set
# got 21 percent correct!
# training fisher face classifier
# size of training set is: 0 images
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-107-07aab80b81d5> in <module>()
#      54 metascore = []
#      55 for i in range(0,10):
# ---> 56     correct = run_recognizer()
#      57     print "got", correct, "percent correct!"
#      58     metascore.append(correct)
#
# <ipython-input-107-07aab80b81d5> in run_recognizer()
#      35     print "training fisher face classifier"
#      36     print "size of training set is:", len(training_labels), "images"
# ---> 37     fishface.train(training_data, np.asarray(training_labels))
#      38
#      39     print "predicting classification set"
#
# error: -------src-dir-------/opencv-2.4.10/modules/contrib/src/facerec.cpp:554: error: (-5) Empty training data was given. You'll need more than one sample to learn a model. in function train

# %%
data
# Out:
# {}

# %% [markdown]
# # 4. Optimizing Dataset

# %%
# For this I used google image search and the chrome plugin ZIG lite to batch-download the images from the results.

# %% [markdown]
# # 5. Looking at the difficulty

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-7f0fcdd637e8> in <module>()
# ----> 1 training_data
#
# NameError: name 'training_data' is not defined

# %%
def run_recognizer():
    training_data, training_labels, prediction_data, prediction_labels = make_sets()
    
    print "training fisher face classifier"
    print "size of training set is:", len(training_labels), "images"
    fishface.train(training_data, np.asarray(training_labels))

    print "predicting classification set"
    cnt = 0
    correct = 0
    incorrect = 0
    for image in prediction_data:
        pred, conf = fishface.predict(image)
        if pred == prediction_labels[cnt]:
            correct += 1
            cnt += 1
        else:
            cv2.imwrite("difficult/%s_%s_%s.jpg" %(emotions[prediction_labels[cnt]], emotions[pred], cnt), image) #<-- this one is new
            incorrect += 1
            cnt += 1
    return ((100*correct)/(correct + incorrect))

# %%
run_recognizer()
# Out:
# training fisher face classifier
# size of training set is: 86 images
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-115-f6c60199d3b7> in <module>()
# ----> 1 run_recognizer()
#
# <ipython-input-113-40954cd9da1f> in run_recognizer()
#       4     print "training fisher face classifier"
#       5     print "size of training set is:", len(training_labels), "images"
# ----> 6     fishface.train(training_data, np.asarray(training_labels))
#       7
#       8     print "predicting classification set"
#
# error: -------src-dir-------/opencv-2.4.10/modules/contrib/src/lda.cpp:1010: error: (-5) At least two classes are needed to perform a LDA. Reason: Only one class was given! in function lda
